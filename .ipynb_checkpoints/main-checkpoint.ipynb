# %%
import hindicorpus as hc

# %% [raw]
# Print all text available:

# %%
hc.raw()
# Out:
# ['कृत्रिम बुद्धि मानव और अन्य जन्तुओं द्वारा प्रदर्शित प्राकृतिक बुद्धि के विपरीत मशीनों द्वारा प्रदर्शित बुद्धि है। कंप्यूटर विज्ञान में कृत्रिम बुद्धि के शोध को "होशियार एजेंट" का अध्ययन माना जाता है. होशियार एजेंट कोई भी ऐसा सयंत्र है जो अपने पर्यावरण को देखकर, अपने लक्ष्य को प्राप्त करने की कोशिश करता है | बोलचाल से, "कृत्रिम बुद्धि/होशियारि " शब्द लागू होता है जब एक मशीन इंसानों की "संज्ञानात्मक" कार्यों की नकल करती है| यह कार्य "सीखने" और "समस्या निवारण" के साथ जोड़ती है। कृत्रिम बुद्धि (प्रज्ञाकल्प, कृत्रिमप्रज्ञा, कृतकधी) का अर् संगणक में अर्पित बुद्धि है। मानव सोचने-विश्लेषण करने व याद रखने का काम भी अपने दिमाग के स्थान पर यन्त्र कम्प्यूटरसे कराना चाहता है।\n\nकृत्रिम बुद्धि, कंप्यूटर विज्ञान का एक शाखा है जो मशीनों और सॉफ्टवेयर को खुफिया के साथ विकसित करता है। 1955 में जॉन मकार्ति ने इसको कृत्रिम बुद्धि का नाम दिया और उसके बारे में "यह विज्ञान और इंजीनियरिंग के बुद्धिमान मशीनों बनाने के" के रूप परिभाषित किया। कृत्रिम बुद्धि अनुसंधान के लक्ष्यों में तर्क, ज्ञान की योजना बना,
# ...

# %% [raw]
# Print all fileids:

# %%
hc.fileids()
# Out:
# ['Technology/Artificial Intelligence.txt',
#  'Technology/Program.txt',
#  'Technology/Computer.txt',
#  'Art/Michelangelo.txt',
#  'Art/DaVinci.txt',
#  'Psychology/Psychology.txt',
#  'Science/Mathematics.txt',
#  'Science/Science.txt',
#  'History/History.txt']

# %% [raw]
# Print all word tokens:

# %%
hc.tokenize()
# Out:
# [['कृत्रिम',
#   'बुद्धि',
#   'मानव',
#   'और',
#   'अन्य',
#   'जन्तुओं',
#   'द्वारा',
#   'प्रदर्शित',
#   'प्राकृतिक',
#   'बुद्धि',
#   'के',
#   'विपरीत',
#   'मशीनों',
#   'द्वारा',
#   'प्रदर्शित',
#   'बुद्धि',
#   'है',
#   'कंप्यूटर',
#   'विज्ञान',
#   'में',
#   'कृत्रिम',
#   'बुद्धि',
#   'के',
#   'शोध',
#   'को',
#   'होशियार',
#   'एजेंट',
#   'का',
#   'अध्ययन',
#   'माना',
#   'जाता',
#   'है',
#   'होशियार',
#   'एजेंट',
#   'कोई',
#   'भी',
#   'ऐसा',
#   'सयंत्र',
#   'है',
#   'जो',
#   'अपने',
#   'पर्यावरण',
#   'को',
#   'देखकर',
#   'अपने',
#   'लक्ष्य',
#   'को',
#   'प्राप्त',
#   'करने',
#   'की',
#   'कोशिश',
#   'करता',
#   'है',
#   'बोलचाल',
#   'से',
#   'कृत्रिम',
#   'बुद्धि',
#   'होशियारि',
#   'शब्द',
#   'लागू',
#   'होता',
#   'है',
#   'जब',
#   'एक',
#   'मशीन',
#   'इंसानों',
#   'की',
#   'संज्ञानात्मक',
#   'कार्यों',
#   'की',
#   'नकल',
#   'करती',
#   'है',
#   'यह',
#   'कार्य',
#   'सीखने',
#   'और',
#   'समस्या',
#   'निवारण',
# ...

# %% [raw]
# Print all sentence tokens:

# %%
hc.sent_tokenize()
# Out:
# [['कृत्रिम बुद्धि मानव और अन्य जन्तुओं द्वारा प्रदर्शित प्राकृतिक बुद्धि के विपरीत मशीनों द्वारा प्रदर्शित बुद्धि है',
#   ' कंप्यूटर विज्ञान में कृत्रिम बुद्धि के शोध को  होशियार एजेंट  का अध्ययन माना जाता है  होशियार एजेंट कोई भी ऐसा सयंत्र है जो अपने पर्यावरण को देखकर  अपने लक्ष्य को प्राप्त करने की कोशिश करता है ',
#   ' बोलचाल से   कृत्रिम बुद्धि होशियारि   शब्द लागू होता है जब एक मशीन इंसानों की  संज्ञानात्मक  कार्यों की नकल करती है',
#   ' यह कार्य  सीखने  और  समस्या निवारण  के साथ जोड़ती है',
#   ' कृत्रिम बुद्धि  प्रज्ञाकल्प  कृत्रिमप्रज्ञा  कृतकधी  का अर् संगणक में अर्पित बुद्धि है',
#   ' मानव सोचने-विश्लेषण करने व याद रखने का काम भी अपने दिमाग के स्थान पर यन्त्र कम्प्यूटरसे कराना चाहता है',
#   '\n\nकृत्रिम बुद्धि  कंप्यूटर विज्ञान का एक शाखा है जो मशीनों और सॉफ्टवेयर को खुफिया के साथ विकसित करता है',
#   '   में जॉन मकार्ति ने इसको कृत्रिम बुद्धि का नाम दिया और उसके बारे में  यह विज्ञान और इंजीनियरिंग के बुद्धिमान मशीनों बनाने के  के रूप परिभाषित किया',
# ...

# %% [raw]
# Print all text in a particular file:

# %%
hc.raw("Technology/Artificial Intelligence.txt")
# Out:
# ['कृत्रिम बुद्धि मानव और अन्य जन्तुओं द्वारा प्रदर्शित प्राकृतिक बुद्धि के विपरीत मशीनों द्वारा प्रदर्शित बुद्धि है। कंप्यूटर विज्ञान में कृत्रिम बुद्धि के शोध को "होशियार एजेंट" का अध्ययन माना जाता है. होशियार एजेंट कोई भी ऐसा सयंत्र है जो अपने पर्यावरण को देखकर, अपने लक्ष्य को प्राप्त करने की कोशिश करता है | बोलचाल से, "कृत्रिम बुद्धि/होशियारि " शब्द लागू होता है जब एक मशीन इंसानों की "संज्ञानात्मक" कार्यों की नकल करती है| यह कार्य "सीखने" और "समस्या निवारण" के साथ जोड़ती है। कृत्रिम बुद्धि (प्रज्ञाकल्प, कृत्रिमप्रज्ञा, कृतकधी) का अर् संगणक में अर्पित बुद्धि है। मानव सोचने-विश्लेषण करने व याद रखने का काम भी अपने दिमाग के स्थान पर यन्त्र कम्प्यूटरसे कराना चाहता है।\n\nकृत्रिम बुद्धि, कंप्यूटर विज्ञान का एक शाखा है जो मशीनों और सॉफ्टवेयर को खुफिया के साथ विकसित करता है। 1955 में जॉन मकार्ति ने इसको कृत्रिम बुद्धि का नाम दिया और उसके बारे में "यह विज्ञान और इंजीनियरिंग के बुद्धिमान मशीनों बनाने के" के रूप परिभाषित किया। कृत्रिम बुद्धि अनुसंधान के लक्ष्यों में तर्क, ज्ञान की योजना बना,
# ...

# %% [raw]
# Print all word tokens without stopwords in a particular file:

# %%
hc.tokenize("Technology/Artificial Intelligence.txt", True)
# Out:
# [['कृत्रिम',
#   'बुद्ध',
#   'मानव',
#   'अन्य',
#   'जन्त',
#   'द्वार',
#   'प्रदर्शित',
#   'प्राकृतिक',
#   'बुद्ध',
#   'विपरीत',
#   'मशीन',
#   'द्वार',
#   'प्रदर्शित',
#   'बुद्ध',
#   'कंप्यूटर',
#   'विज्ञान',
#   'कृत्रिम',
#   'बुद्ध',
#   'शोध',
#   'होशियार',
#   'एजेंट',
#   'अध्ययन',
#   'मा',
#   'होशियार',
#   'एजेंट',
#   'ऐस',
#   'सयंत्र',
#   'अप',
#   'पर्यावरण',
#   'देख',
#   'अप',
#   'लक्ष्य',
#   'प्राप्त',
#   'कोशिश',
#   'बोलचाल',
#   'कृत्रिम',
#   'बुद्ध',
#   'होशियार',
#   'शब्द',
#   'लाग',
#   'मशीन',
#   'इंसान',
#   'संज्ञानात्मक',
#   'कार्य',
#   'नकल',
#   'कार्य',
#   'सीख',
#   'समस्य',
#   'निवारण',
#   'जोड़',
#   'कृत्रिम',
#   'बुद्ध',
#   'प्रज्ञाकल्प',
#   'कृत्रिमप्रज्ञ',
#   'कृतकध',
#   'अर्',
#   'संगणक',
#   'अर्पित',
#   'बुद्ध',
#   'मानव',
#   'याद',
#   'रख',
#   'काम',
#   'अप',
#   'दिमाग',
#   'स्थान',
#   'यन्त्र',
#   'कम्प्यूटरस',
#   'चाह',
#   '\n\nकृत्रिम',
#   'बुद्ध',
#   'कंप्यूटर',
#   'विज्ञान',
#   'शाख',
# ...

# %% [raw]
# Print all word tokens with stopwords in a particular file:

# %%
hc.tokenize("Technology/Artificial Intelligence.txt", False)
# Out:
# [['कृत्रिम',
#   'बुद्धि',
#   'मानव',
#   'और',
#   'अन्य',
#   'जन्तुओं',
#   'द्वारा',
#   'प्रदर्शित',
#   'प्राकृतिक',
#   'बुद्धि',
#   'के',
#   'विपरीत',
#   'मशीनों',
#   'द्वारा',
#   'प्रदर्शित',
#   'बुद्धि',
#   'है',
#   'कंप्यूटर',
#   'विज्ञान',
#   'में',
#   'कृत्रिम',
#   'बुद्धि',
#   'के',
#   'शोध',
#   'को',
#   'होशियार',
#   'एजेंट',
#   'का',
#   'अध्ययन',
#   'माना',
#   'जाता',
#   'है',
#   'होशियार',
#   'एजेंट',
#   'कोई',
#   'भी',
#   'ऐसा',
#   'सयंत्र',
#   'है',
#   'जो',
#   'अपने',
#   'पर्यावरण',
#   'को',
#   'देखकर',
#   'अपने',
#   'लक्ष्य',
#   'को',
#   'प्राप्त',
#   'करने',
#   'की',
#   'कोशिश',
#   'करता',
#   'है',
#   'बोलचाल',
#   'से',
#   'कृत्रिम',
#   'बुद्धि',
#   'होशियारि',
#   'शब्द',
#   'लागू',
#   'होता',
#   'है',
#   'जब',
#   'एक',
#   'मशीन',
#   'इंसानों',
#   'की',
#   'संज्ञानात्मक',
#   'कार्यों',
#   'की',
#   'नकल',
#   'करती',
#   'है',
#   'यह',
#   'कार्य',
#   'सीखने',
#   'और',
#   'समस्या',
#   'निवारण',
# ...

# %% [raw]
# Print all sentence tokens in a particular file:

# %%
hc.sent_tokenize("Technology/Artificial Intelligence.txt")
# Out:
# [['कृत्रिम बुद्धि मानव और अन्य जन्तुओं द्वारा प्रदर्शित प्राकृतिक बुद्धि के विपरीत मशीनों द्वारा प्रदर्शित बुद्धि है',
#   ' कंप्यूटर विज्ञान में कृत्रिम बुद्धि के शोध को  होशियार एजेंट  का अध्ययन माना जाता है  होशियार एजेंट कोई भी ऐसा सयंत्र है जो अपने पर्यावरण को देखकर  अपने लक्ष्य को प्राप्त करने की कोशिश करता है ',
#   ' बोलचाल से   कृत्रिम बुद्धि होशियारि   शब्द लागू होता है जब एक मशीन इंसानों की  संज्ञानात्मक  कार्यों की नकल करती है',
#   ' यह कार्य  सीखने  और  समस्या निवारण  के साथ जोड़ती है',
#   ' कृत्रिम बुद्धि  प्रज्ञाकल्प  कृत्रिमप्रज्ञा  कृतकधी  का अर् संगणक में अर्पित बुद्धि है',
#   ' मानव सोचने-विश्लेषण करने व याद रखने का काम भी अपने दिमाग के स्थान पर यन्त्र कम्प्यूटरसे कराना चाहता है',
#   '\n\nकृत्रिम बुद्धि  कंप्यूटर विज्ञान का एक शाखा है जो मशीनों और सॉफ्टवेयर को खुफिया के साथ विकसित करता है',
#   '   में जॉन मकार्ति ने इसको कृत्रिम बुद्धि का नाम दिया और उसके बारे में  यह विज्ञान और इंजीनियरिंग के बुद्धिमान मशीनों बनाने के  के रूप परिभाषित किया',
# ...

# %% [raw]
# Search for files with keyword:

# %%
hc.fileids_search("मशीनों")
# Out:
# ['Technology/Artificial Intelligence.txt']

# %%
hc.play("data/Psychology/Psychology.mp3")

# %%
hc.play_sentence("data/Psychology/Psychology.mp3", 1)
